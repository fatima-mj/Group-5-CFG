# %%
import pandas as pd
import math
import datetime
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np

# %%
cp_sales = pd.read_csv('C:/Users/avuha/Downloads/CryptoPunks_.csv')
cp_sales
# Out:
#                  DateTime  Sales (USD)
# 0     2017-06-23 00:00:00      1455.93
# 1     2017-06-24 00:00:00       883.03
# 2     2017-06-25 00:00:00       556.39
# 3     2017-06-26 00:00:00      1107.41
# 4     2017-06-27 00:00:00      2215.28
# ...                   ...          ...
# 1370  2022-10-23 00:00:00    826675.83
# 1371  2022-10-24 00:00:00    713878.82
# 1372  2022-10-25 00:00:00    636740.25
# 1373  2022-10-26 00:00:00   1432022.64
# 1374  2022-10-27 00:00:00    103443.63
#
# [1375 rows x 2 columns]

# %%
cp_sales.describe()
# Out:
#         Sales (USD)
# count  1.375000e+03
# mean   1.473423e+06
# std    6.195098e+06
# min    0.000000e+00
# 25%    2.264250e+02
# 50%    1.804060e+03
# 75%    7.712323e+05
# max    1.435515e+08

# %%
cp_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1375 entries, 0 to 1374
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DateTime     1375 non-null   object
#  1   Sales (USD)  1375 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 21.6+ KB

# %%
cp_sales['DateTime'] = cp_sales['DateTime'].str.replace('00:00:00','')

# %%
cp_sales['DateTime'] = pd.to_datetime(cp_sales['DateTime'])
cp_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1375 entries, 0 to 1374
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DateTime     1375 non-null   datetime64[ns]
#  1   Sales (USD)  1375 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 21.6 KB

# %%
bayc_sales = pd.read_csv('C:/Users/avuha/Downloads/BAYC_sales.csv')
bayc_sales
# Out:
#                 DateTime  Sales (USD)
# 0    2021-04-23 00:00:00      2074.27
# 1    2021-04-24 00:00:00      2862.84
# 2    2021-04-25 00:00:00      1472.33
# 3    2021-04-26 00:00:00      1616.64
# 4    2021-04-27 00:00:00      2540.51
# ..                   ...          ...
# 548  2022-10-23 00:00:00    886101.51
# 549  2022-10-24 00:00:00    403949.22
# 550  2022-10-25 00:00:00   1596218.49
# 551  2022-10-26 00:00:00   1794182.78
# 552  2022-10-27 00:00:00    139202.39
#
# [553 rows x 2 columns]

# %%
bayc_sales.describe()
# Out:
#         Sales (USD)
# count  5.530000e+02
# mean   4.456006e+06
# std    5.879608e+06
# min    1.472330e+03
# 25%    1.215356e+06
# 50%    2.643237e+06
# 75%    5.434889e+06
# max    5.371694e+07

# %%
bayc_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DateTime     553 non-null    object
#  1   Sales (USD)  553 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 8.8+ KB

# %%
bayc_sales['DateTime'] = bayc_sales['DateTime'].str.replace('00:00:00','')

# %%
bayc_sales['DateTime'] = pd.to_datetime(bayc_sales['DateTime'])
bayc_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DateTime     553 non-null    datetime64[ns]
#  1   Sales (USD)  553 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 8.8 KB

# %% [markdown]
# ## Cleaning each dataframe

# %%
cp_sales.rename(columns = {'Sales (USD)':'CP Sales(USD)'}, inplace = True)
cp_sales.rename(columns = {'DateTime':'CP DateTime'}, inplace = True)
cp_sales=cp_sales.dropna()
cp_sales
# Out:
#      CP DateTime  CP Sales(USD)
# 0     2017-06-23        1455.93
# 1     2017-06-24         883.03
# 2     2017-06-25         556.39
# 3     2017-06-26        1107.41
# 4     2017-06-27        2215.28
# ...          ...            ...
# 1370  2022-10-23      826675.83
# 1371  2022-10-24      713878.82
# 1372  2022-10-25      636740.25
# 1373  2022-10-26     1432022.64
# 1374  2022-10-27      103443.63
#
# [1375 rows x 2 columns]

# %%
cp_sales['CP Sales(USD)'] = cp_sales['CP Sales(USD)'].astype('int64')
cp_sales
# Out:
#      CP DateTime  CP Sales(USD)
# 0     2017-06-23           1455
# 1     2017-06-24            883
# 2     2017-06-25            556
# 3     2017-06-26           1107
# 4     2017-06-27           2215
# ...          ...            ...
# 1370  2022-10-23         826675
# 1371  2022-10-24         713878
# 1372  2022-10-25         636740
# 1373  2022-10-26        1432022
# 1374  2022-10-27         103443
#
# [1375 rows x 2 columns]

# %%
bayc_sales.rename(columns = {'Sales (USD)':'BAYC Sales(USD)'}, inplace = True)
bayc_sales.rename(columns = {'DateTime':'BAYC DateTime'}, inplace = True)
bayc_sales=bayc_sales.dropna()
bayc_sales
# Out:
#     BAYC DateTime  BAYC Sales(USD)
# 0      2021-04-23          2074.27
# 1      2021-04-24          2862.84
# 2      2021-04-25          1472.33
# 3      2021-04-26          1616.64
# 4      2021-04-27          2540.51
# ..            ...              ...
# 548    2022-10-23        886101.51
# 549    2022-10-24        403949.22
# 550    2022-10-25       1596218.49
# 551    2022-10-26       1794182.78
# 552    2022-10-27        139202.39
#
# [553 rows x 2 columns]

# %%
bayc_sales['BAYC Sales(USD)'] = bayc_sales['BAYC Sales(USD)'].astype('int64')
bayc_sales
# Out:
#     BAYC DateTime  BAYC Sales(USD)
# 0      2021-04-23             2074
# 1      2021-04-24             2862
# 2      2021-04-25             1472
# 3      2021-04-26             1616
# 4      2021-04-27             2540
# ..            ...              ...
# 548    2022-10-23           886101
# 549    2022-10-24           403949
# 550    2022-10-25          1596218
# 551    2022-10-26          1794182
# 552    2022-10-27           139202
#
# [553 rows x 2 columns]

# %% [markdown]
# ## Combining the dataframes

# %%
merged_df = pd.concat([cp_sales, bayc_sales], axis=1)
merged_df
# Out:
#      CP DateTime  CP Sales(USD) BAYC DateTime  BAYC Sales(USD)
# 0     2017-06-23           1455    2021-04-23           2074.0
# 1     2017-06-24            883    2021-04-24           2862.0
# 2     2017-06-25            556    2021-04-25           1472.0
# 3     2017-06-26           1107    2021-04-26           1616.0
# 4     2017-06-27           2215    2021-04-27           2540.0
# ...          ...            ...           ...              ...
# 1370  2022-10-23         826675           NaT              NaN
# 1371  2022-10-24         713878           NaT              NaN
# 1372  2022-10-25         636740           NaT              NaN
# 1373  2022-10-26        1432022           NaT              NaN
# 1374  2022-10-27         103443           NaT              NaN
#
# [1375 rows x 4 columns]

# %% [markdown]
# ## By merging the datasets together, we are able to have a closer comparative analysis of the sales of CryptoPunk NFTs and Bored Ape Yacht Club from the period of 2017 to 2022. The output below shows us how significantly bigger Bored Ape sales have grown in comparison to CryptoPunk's.

# %%
merged_df.describe()
# Out:
#        CP Sales(USD)  BAYC Sales(USD)
# count   1.375000e+03     5.530000e+02
# mean    1.473422e+06     4.456005e+06
# std     6.195098e+06     5.879608e+06
# min     0.000000e+00     1.472000e+03
# 25%     2.260000e+02     1.215356e+06
# 50%     1.804000e+03     2.643236e+06
# 75%     7.712320e+05     5.434889e+06
# max     1.435515e+08     5.371694e+07

# %%
merged_df.plot(x='CP DateTime', y='CP Sales(USD)', kind='line')

plt.title("Crypto Punk Sales 2018-2022")
plt.xlabel("Time period")
plt.ylabel("Sales (USD)")

plt.show()

# %% [markdown]
# ### The contrast in sales growth between the two NFT collections is best illustrated by the above line chart where we can see that Crypto Punks has experienced long periods of no sales growth from the year 2018 to 2021. Sales growth begins to spike by the end of 2021 which was due to increased demand in cryptocurrencies and growth of various digital currencies hitting the mainstream.

# %%
merged_df.plot(x='BAYC DateTime', y='BAYC Sales(USD)')

plt.title("Bored Ape Sales 2021-2022")
plt.xlabel("Time period")
plt.ylabel("Sales (USD)")

plt.show()

# %% [markdown]
# ### Bored Ape had fluctuating growth in sales through mid 2021 to mid 2022, similarly illustrating the growing interest in cryptocurrencies during this period. Unlike Crypto Punks, Bored Apes had more frequent periods of spikes in sales growth during this period which only began to steadily decline in mid 2022. Based on these findings, we can infer that there is a higher probability for Bored Ape NFTs to experience spikes in sales in the upcoming year of 2023 than Crypto Punk NFTs.
